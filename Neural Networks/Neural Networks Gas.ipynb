# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import tensorflow as tf
tf.debugging.set_log_device_placement(False) 
import warnings
warnings.filterwarnings('ignore')

# %%
tf.random.set_seed(14)

# %%
raw_data = pd.read_csv("gas_turbines.csv")
raw_data.head() 
#TEY is the variable we should predict.
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df = raw_data.copy() 
df = df.drop(['AFDP','GTEP','TIT','TAT','CDP','CO','NOX'],axis=1)
df.head()
# Out:
#        AT      AP      AH     TEY
# 0  6.8594  1007.9  96.799  114.70
# 1  6.7850  1008.4  97.118  114.72
# 2  6.8977  1008.8  95.939  114.71
# 3  7.0569  1009.2  95.249  114.72
# 4  7.3978  1009.7  95.150  114.72

# %%
df.info() #No null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   TEY     15039 non-null  float64
# dtypes: float64(4)
# memory usage: 470.1 KB

# %%
df.describe()
# Out:
#                  AT           AP            AH           TEY
# count  15039.000000  15039.00000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174    134.188464
# std        7.574323      6.41076     13.793439     15.829717
# min        0.522300    985.85000     30.344000    100.170000
# 25%       11.408000   1008.90000     69.750000    127.985000
# 50%       18.186000   1012.80000     82.266000    133.780000
# 75%       23.862500   1016.90000     90.043500    140.895000
# max       34.929000   1034.20000    100.200000    174.610000

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(data=df, orient="v", palette="Set2")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train | Split dataset

# %%
X =df.iloc[:,:-1]
Y = df.iloc[:,-1]


X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3)

# %%
y_train=np.reshape(y_train.to_numpy(), (-1,1)) #https://stackoverflow.com/questions/57192304/numpy-python-exception-data-must-be-1-dimensional
y_test=np.reshape(y_test.to_numpy(), (-1,1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

print(scaler_x.fit(X_train))
xtrain_scale=scaler_x.transform(X_train)

print(scaler_x.fit(X_test))
xtest_scale=scaler_x.transform(X_test)

print(scaler_y.fit(y_train))
ytrain_scale=scaler_y.transform(y_train)

print(scaler_y.fit(y_test))
ytest_scale=scaler_y.transform(y_test)
# Out:
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()

# %%
len(xtrain_scale)
# Out:
# 10527

# %% [markdown]
# # Visualizing the data

# %%
sns.pairplot(df,palette='deep')

# %% [markdown]
# # Neural Network Modelling

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
import keras
keras. __version__ #init method is not available in this mdethod
# Out:
# '2.8.0'

# %%
# create model
model1 = Sequential()
model1.add(Dense(4, input_dim=3, kernel_initializer='normal', activation='relu'))
model1.add(Dense(2106,kernel_initializer='normal', activation='relu'))
model1.add(Dense(1, activation='linear'))
# Compile model
model1.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse','mae'])
# Fit the model
hist1 = model1.fit(xtrain_scale, ytrain_scale, validation_split=0.33, epochs=100, batch_size=150)
#At epoch 50, mse and mae just keeps oscillating back and forth
# Out:
# Epoch 1/100
# 2023-01-05 00:50:10.670916: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0724 - mse: 0.0724 - mae: 0.2055 - val_loss: 0.0459 - val_mse: 0.0459 - val_mae: 0.1566
# Epoch 2/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0461 - mse: 0.0461 - mae: 0.1555 - val_loss: 0.0451 - val_mse: 0.0451 - val_mae: 0.1515
# Epoch 3/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0455 - mse: 0.0455 - mae: 0.1525 - val_loss: 0.0462 - val_mse: 0.0462 - val_mae: 0.1635
# Epoch 4/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0457 - mse: 0.0457 - mae: 0.1569 - val_loss: 0.0445 - val_mse: 0.0445 - val_mae: 0.1522
# Epoch 5/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0449 - mse: 0.0449 - mae: 0.1537 - val_loss: 0.0442 - val_mse: 0.0442 - val_mae: 0.1533
# Epoch 6/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0444 - mse: 0.0444 - mae: 0.1539 - val_loss: 0.0437 - val_mse: 0.0437 - val_mae: 0.1529
# Epoch 7/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0438 - mse: 0.0438 - mae: 0.1529 - val_loss: 0.0429 - val_mse: 0.0429 - val_mae: 0.1529
# Epoch 8/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0434 - mse: 0.0434 - mae: 0.1558 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1522
# Epoch 9/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0424 - mse: 0.0424 - mae: 0.1542 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1541
# Epoch 10/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0419 - mse: 0.0419 - mae: 0.1553 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1581
# Epoch 11/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1567 - val_loss: 0.0406 - val_mse: 0.0406 - val_mae: 0.1563
# Epoch 12/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1571 - val_loss: 0.0405 - val_mse: 0.0405 - val_mae: 0.1555
# Epoch 13/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0407 - mse: 0.0407 - mae: 0.1575 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1572
# Epoch 14/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1573 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1645
# Epoch 15/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0421 - mse: 0.0421 - mae: 0.1628 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1560
# Epoch 16/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1576 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1576
# Epoch 17/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1575 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1564
# Epoch 18/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1577 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1573
# Epoch 19/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1582 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1568
# Epoch 20/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0399 - mse: 0.0399 - mae: 0.1577 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1595
# Epoch 21/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1607 - val_loss: 0.0411 - val_mse: 0.0411 - val_mae: 0.1596
# Epoch 22/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1593 - val_loss: 0.0400 - val_mse: 0.0400 - val_mae: 0.1605
# Epoch 23/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1577 - val_loss: 0.0395 - val_mse: 0.0395 - val_mae: 0.1578
# Epoch 24/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1576 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1569
# Epoch 25/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1571 - val_loss: 0.0397 - val_mse: 0.0397 - val_mae: 0.1602
# Epoch 26/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1590 - val_loss: 0.0398 - val_mse: 0.0398 - val_mae: 0.1569
# Epoch 27/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1573 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1571
# Epoch 28/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1580 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1570
# Epoch 29/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1577 - val_loss: 0.0392 - val_mse: 0.0392 - val_mae: 0.1561
# Epoch 30/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1577 - val_loss: 0.0406 - val_mse: 0.0406 - val_mae: 0.1595
# Epoch 31/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1579 - val_loss: 0.0395 - val_mse: 0.0395 - val_mae: 0.1571
# Epoch 32/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1580 - val_loss: 0.0391 - val_mse: 0.0391 - val_mae: 0.1562
# Epoch 33/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1577 - val_loss: 0.0407 - val_mse: 0.0407 - val_mae: 0.1588
# Epoch 34/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1582 - val_loss: 0.0391 - val_mse: 0.0391 - val_mae: 0.1564
# Epoch 35/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1558 - val_loss: 0.0391 - val_mse: 0.0391 - val_mae: 0.1580
# Epoch 36/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1578 - val_loss: 0.0391 - val_mse: 0.0391 - val_mae: 0.1575
# Epoch 37/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1568 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1569
# Epoch 38/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1566 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1572
# Epoch 39/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1562 - val_loss: 0.0407 - val_mse: 0.0407 - val_mae: 0.1600
# Epoch 40/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1588 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1633
# Epoch 41/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1598 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1599
# Epoch 42/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1565 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1590
# Epoch 43/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1580 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1576
# Epoch 44/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1572 - val_loss: 0.0389 - val_mse: 0.0389 - val_mae: 0.1557
# Epoch 45/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1571 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1572
# Epoch 46/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1575 - val_loss: 0.0397 - val_mse: 0.0397 - val_mae: 0.1574
# Epoch 47/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1581 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1548
# Epoch 48/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1559 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1575
# Epoch 49/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1582 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1620
# Epoch 50/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1582 - val_loss: 0.0387 - val_mse: 0.0387 - val_mae: 0.1566
# Epoch 51/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1568 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1578
# Epoch 52/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1572 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1575
# Epoch 53/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1572 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1594
# Epoch 54/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1561 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1573
# Epoch 55/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1562 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1589
# Epoch 56/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1579 - val_loss: 0.0409 - val_mse: 0.0409 - val_mae: 0.1611
# Epoch 57/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1570 - val_loss: 0.0387 - val_mse: 0.0387 - val_mae: 0.1575
# Epoch 58/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1573 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1566
# Epoch 59/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1568 - val_loss: 0.0404 - val_mse: 0.0404 - val_mae: 0.1601
# Epoch 60/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1575 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1575
# Epoch 61/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1584 - val_loss: 0.0393 - val_mse: 0.0393 - val_mae: 0.1583
# Epoch 62/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1576 - val_loss: 0.0389 - val_mse: 0.0389 - val_mae: 0.1564
# Epoch 63/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1565 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1582
# Epoch 64/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1566 - val_loss: 0.0393 - val_mse: 0.0393 - val_mae: 0.1572
# Epoch 65/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1581 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1555
# Epoch 66/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1571 - val_loss: 0.0397 - val_mse: 0.0397 - val_mae: 0.1599
# Epoch 67/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1589 - val_loss: 0.0394 - val_mse: 0.0394 - val_mae: 0.1571
# Epoch 68/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1562 - val_loss: 0.0386 - val_mse: 0.0386 - val_mae: 0.1570
# Epoch 69/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1570 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1567
# Epoch 70/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1569 - val_loss: 0.0390 - val_mse: 0.0390 - val_mae: 0.1591
# Epoch 71/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1561 - val_loss: 0.0385 - val_mse: 0.0385 - val_mae: 0.1558
# Epoch 72/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1577 - val_loss: 0.0392 - val_mse: 0.0392 - val_mae: 0.1568
# Epoch 73/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1560 - val_loss: 0.0385 - val_mse: 0.0385 - val_mae: 0.1556
# Epoch 74/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1560 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1571
# Epoch 75/100
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1574 - val_loss: 0.0388 - val_mse: 0.0388 - val_mae: 0.1575
# Epoch 76/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1563 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1552
# Epoch 77/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1573 - val_loss: 0.0384 - val_mse: 0.0384 - val_mae: 0.1536
# Epoch 78/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1552 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1544
# Epoch 79/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1570 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1630
# Epoch 80/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1580 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1595
# Epoch 81/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1559 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1553
# Epoch 82/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1559 - val_loss: 0.0386 - val_mse: 0.0386 - val_mae: 0.1555
# Epoch 83/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1551 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1554
# Epoch 84/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1562 - val_loss: 0.0382 - val_mse: 0.0382 - val_mae: 0.1546
# Epoch 85/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1549 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1547
# Epoch 86/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1554 - val_loss: 0.0392 - val_mse: 0.0392 - val_mae: 0.1568
# Epoch 87/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1553 - val_loss: 0.0411 - val_mse: 0.0411 - val_mae: 0.1622
# Epoch 88/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1573 - val_loss: 0.0396 - val_mse: 0.0396 - val_mae: 0.1586
# Epoch 89/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1555 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1542
# Epoch 90/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1556 - val_loss: 0.0401 - val_mse: 0.0401 - val_mae: 0.1598
# Epoch 91/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1573 - val_loss: 0.0385 - val_mse: 0.0385 - val_mae: 0.1552
# Epoch 92/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0381 - mse: 0.0381 - mae: 0.1545 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1536
# Epoch 93/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0381 - mse: 0.0381 - mae: 0.1543 - val_loss: 0.0387 - val_mse: 0.0387 - val_mae: 0.1558
# Epoch 94/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1547 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1541
# Epoch 95/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0379 - mse: 0.0379 - mae: 0.1541 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1549
# Epoch 96/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1555 - val_loss: 0.0380 - val_mse: 0.0380 - val_mae: 0.1544
# Epoch 97/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1552 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1549
# Epoch 98/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1546 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1532
# Epoch 99/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0379 - mse: 0.0379 - mae: 0.1541 - val_loss: 0.0378 - val_mse: 0.0378 - val_mae: 0.1529
# Epoch 100/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0379 - mse: 0.0379 - mae: 0.1537 - val_loss: 0.0379 - val_mse: 0.0379 - val_mae: 0.1534

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 2106)              10530
#
#  dense_2 (Dense)             (None, 1)                 2107
#
# =================================================================
# Total params: 12,653
# Trainable params: 12,653
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Evaluation

# %%
y_predict = model1.predict(xtest_scale)

# %%
plt.plot(ytest_scale)
plt.plot(y_predict)
plt.title('Predicted V/s Actual')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show() #Neural Networks is not a good model for predicting a regression problem

# %%
print(hist1.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
hist1_df = pd.DataFrame(hist1.history)
hist1_df["epoch"]=hist1.epoch
hist1_df.tail()
# Out:
#         loss       mse       mae  val_loss   val_mse   val_mae  epoch
# 95  0.037992  0.037992  0.155483  0.037985  0.037985  0.154435     95
# 96  0.038346  0.038346  0.155203  0.038096  0.038096  0.154923     96
# 97  0.037965  0.037965  0.154611  0.038079  0.038079  0.153172     97
# 98  0.037860  0.037860  0.154089  0.037801  0.037801  0.152929     98
# 99  0.037860  0.037860  0.153667  0.037914  0.037914  0.153416     99

# %% [markdown]
# # Visualize Training History

# %%
# summarize history for Loss

sns.set(rc={'figure.figsize':(6,4)})

plt.plot(hist1.history['loss'])
plt.plot(hist1.history['val_loss'])
plt.title('model1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist1.history['mse'])
plt.plot(hist1.history['val_mse'])
plt.title('model1 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
